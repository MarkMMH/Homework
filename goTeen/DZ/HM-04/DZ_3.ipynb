# %%
a = int(input())
b = int(input())
a+=1
for x in range(a,b):
    x**x
    print(x)

# %%
char = ','
i = str(input('Enter char'))
for i in char:
    print(i)

# %%
cities = ('kyiv','Brovary','Lviv','Kharkiv')
city = str(input(' '))
while city in cities:
    print('Уже были')
    break
if not city in cities:
    print('Будем впервые')
