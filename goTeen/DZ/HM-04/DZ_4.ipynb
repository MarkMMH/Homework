# %%
continent =('Africa')               
continent2 = ('Antarctica')
west_list = ['Africa', 'Asia', 'Antarctica']
north_list = ['Africa', 'Antarctica', 'Eurasia', ' Australia']

west_list.extend(north_list)
west_list.pop(0)
west_list.pop(1)
print(west_list)

west_list.sort('')
# Out:
# ['Asia', 'Africa', 'Antarctica', 'Eurasia', ' Australia']

# %%
list = [
['phone' 'Apple', 30000],

['notebook', 'Lenovo', 12000],

['notebook', 'Samsung', 24000],

['phone', 'Mi', 5600],
]
